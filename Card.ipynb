# %% [markdown]
# <a href="https://colab.research.google.com/github/wlgp8563/RA_CardPrework/blob/main/Card.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install funpymodeling
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.5/215.5 KB 5.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2344 sha256=1f457692fdc18e8c9c0a0866e078c64892f8cca74b29da96b8401bdbc33f9e93
#   Stored in directory: /root/.cache/pip/wheels/14/25/f7/1cc0956978ae479e75140219088deb7a36f60459df242b1a72
# Successfully built sklearn
# ...
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.11.2
#     Uninstalling seaborn-0.11.2:
#       Successfully uninstalled seaborn-0.11.2
# ...

# %%
import pandas as pd
from funpymodeling.exploratory import freq_tbl, status, profiling_num, cat_vars, num_vars
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import openpyxl

# %%
import plotly.express as px
import plotly.graph_objects as go
import nltk
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud
from collections import Counter
import re

# %%
from google.colab import drive     #구글 내 드라이브에 필요한 데이터셋 저장 후 불러오기 위해 사용용
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
hcard_df1 = pd.read_excel('/content/drive/MyDrive/AMT_StoryDataset_ver1.2(11July2022)-no1.xlsx', sheet_name='happy_ending_story', engine='openpyxl')
print(hcard_df1)
# Out:
#     card1  card2 card3                                              text1  \
# 0      A_1  A_40  A_35  Tom was sick and spent many days in the hospit...
# 1     B_33  A_10  B_20   Jessica was fast asleep dreaming in her bedroom.
# 2      A_6  A_25  A_17  Gary and Terry played a fast paced and competi...
# 3     B_11  B_27  B_13              John is a poor man and does odd jobs.
# 4     A_39  A_23  B_30  She was worried that the store would not have ...
# ..     ...   ...   ...                                                ...
# 345     A3    A6    A8  Everyone told that not play video games for lo...
# 346   A-36  B-38   B-6  Caroline return to home from school  with thin...
# 347    A_1  A_28  B_23  Felix was admitted in a hospital where he was ...
# 348   A_36  A_22  A_35  Mike had a crush on Missy, but he was too scar...
# 349   B_17  A_11   A_8  Noah attends a singing competition and he is v...
#
#                                                  text2  \
# ...

# %%
scard_df1 = pd.read_excel('/content/drive/MyDrive/AMT_StoryDataset_ver1.2(11July2022)-no1.xlsx', sheet_name='sad_ending_story', engine='openpyxl')
print(scard_df1)
# Out:
#     card1 card2 card3                                              text1  \
# 0    A_32  A_29  B_32  Marvin bought a new house and furnished it ele...
# 1    A_11  B_20   B_8  Jim mustered up enough courage and proposed to...
# 2    A_11  B_11  B_17  John promised to singing with his friends cult...
# 3    B_38  B_32  B_39   Betty was getting ready to meet her friend Eddie
# 4     A_6  B_24   A_1  Tom was playing football on the road nearby hi...
# ..    ...   ...   ...                                                ...
# 350  B_40  B_30  B_19  Richard receives an email invite for a birthda...
# 351   A_7  A_28  B_32             The boy wants to become a military man
# 352  A_30  B_21  A_21              Mary was pregnant with a little girl.
# 353  A-19  A-31   B-6           Frank's car gets hit on his way to work.
# 354  A_39  A_19   A_1    A thief trying to stole the things from a shop.
#
#                                                  text2  \
# ...

# %%
hcard_df2 = pd.read_excel('/content/drive/MyDrive/AMT_StoryDataset_ver1.2(11July2022)-no2.xlsx', sheet_name='happy_ending_story', engine='openpyxl')
print(hcard_df2)
# Out:
#     card1 card2 card3                                              text1  \
# 0     A_1  A_40  A_35  Tom was sick and spent many days in the hospit...
# 1    B_33  A_10  B_20   Jessica was fast asleep dreaming in her bedroom.
# 2     A_6  A_25  A_17  Gary and Terry played a fast paced and competi...
# 3    B_11  B_27  B_13              John is a poor man and does odd jobs.
# 4    A_39  A_23  B_30  She was worried that the store would not have ...
# ..    ...   ...   ...                                                ...
# 345    A3    A6    A8  Everyone told that not play video games for lo...
# 346  A-36  B-38   B-6  Caroline return to home from school  with thin...
# 347   A_1  A_28  B_23  Felix was admitted in a hospital where he was ...
# 348  A_36  A_22  A_35  Mike had a crush on Missy, but he was too scar...
# 349  B_17  A_11   A_8  Noah attends a singing competition and he is v...
#
#                                                  text2  \
# ...

# %%
scard_df2 = pd.read_excel('/content/drive/MyDrive/AMT_StoryDataset_ver1.2(11July2022)-no2.xlsx', sheet_name='sad_ending_story', engine='openpyxl')

# %%
hcard_df3 = pd.read_excel('/content/drive/MyDrive/AMT_StoryDataset_ver1.2(11July2022)-no3.xlsx', sheet_name='happy_ending_story', engine='openpyxl')

# %%
scard_df3 = pd.read_excel('/content/drive/MyDrive/AMT_StoryDataset_ver1.2(11July2022)-no3.xlsx', sheet_name='sad_ending_story', engine='openpyxl')

# %%
hcard_df1.head(5)
# Out:
#   card1  card2 card3                                              text1  \
# 0    A_1  A_40  A_35  Tom was sick and spent many days in the hospit...
# 1   B_33  A_10  B_20   Jessica was fast asleep dreaming in her bedroom.
# 2    A_6  A_25  A_17  Gary and Terry played a fast paced and competi...
# 3   B_11  B_27  B_13              John is a poor man and does odd jobs.
# 4   A_39  A_23  B_30  She was worried that the store would not have ...
#
#                                                text2  \
# 0                 A new doctor came in to treat Tom.
# 1  She was being chased by an unknown shadow in h...
# 2  The game got so heated that the boys got into ...
# 3                He tries his luck by playing poker.
# 4  She bought what she was able to find at the st...
#
#                                                text3  Interestingness  \
# 0  Tom is now fully healed and happy with his new...              1.0
# ...

# %%
hcard_df1['Interestingness']
# Out:
# 0      1.0
# 1      2.0
# 2      2.0
# 3      1.0
# 4      1.0
#       ...
# 345    1.0
# 346    1.0
# 347    1.0
# 348    1.0
# 349    1.0
# Name: Interestingness, Length: 350, dtype: float64

# %%
hcard1_f = hcard_df1[(hcard_df1['Interestingness'] == 1.0) & (hcard_df1['비흥미 요인 (평점 1)'] == '단순 사실 열거')]
hcard1_f
# Out:
#     card1  card2 card3                                              text1  \
# 0      A_1  A_40  A_35  Tom was sick and spent many days in the hospit...
# 4     A_39  A_23  B_30  She was worried that the store would not have ...
# 6     A_13  B_19  B_14  Melissa Jones is lucky because she can eat all...
# 9      A_1  A_40  A_12  Lisa is very upset because she is sick in the ...
# 10    A_30  A_40  A_27           Anna Jonas is expecting her first child.
# ..     ...   ...   ...                                                ...
# 335   A_18  B_33  A_12            It was a stormy night that scared Jill.
# 337   A_29  A_15  B_13       Michael is a hard working finance executive.
# 338   A_30  B_33  A_27               Losi was on her ninth month of labor
# 339    B_5  A_29  A_40  As an ordinary boy, Jack decides to become a p...
# 349   B_17  A_11   A_8  Noah attends a singing competition and he is v...
#
#                                                  text2  \
# ...

# %%
hcard1_l = hcard_df1[(hcard_df1['Interestingness'] == 1.0) & (hcard_df1['비흥미 요인 (평점 1)'] == '과정 생략/인과성 또는 개연성 부족')]
hcard1_l
# Out:
#     card1  card2 card3                                              text1  \
# 7     A_30   A_6   A_8  Anna watched a lot of football matches when sh...
# 17    B_25  B_21  A_22  Then Lisa's owner gets a dog and she has a won...
# 25    B_33  B_39  B_23  Sally had a hard time sleeping the night befor...
# 45     A_6   A_7   A_8   Kevin loves to play foot ball in his school days
# 57    B_32  B_27  B_23               John lost his money at his business.
# 64    B_33  A_37  B_31                    She has no friends so she sleep
# 67     A_3  A_24  A_35  Alex was feeling alone and isolated doing noth...
# 136    A_3   B_2   B_1        John got a new controller for his birthday.
# 144   A_13  A_20  A_29                  The boy didn't like to eat a food
# 145   A_27  A_26  B_31        Arnold has no friends so  he playing lonely
# 151   A_25  B_11  A_35      The two friends are fighting with no reason .
# 154   B_17  B_13  B_29        A man gets a distressing call from his mom.
# ...

# %%
hcard1_r = hcard_df1[(hcard_df1['Interestingness'] == 1.0) & (hcard_df1['비흥미 요인 (평점 1)'] == '예측 가능한 전개 또는 결말')]
hcard1_r
# Out:
#    card1  card2 card3                                              text1  \
# 30    A-1  A_31   A_6  Bobby was frightened because he was in the hos...
#
#                                   text2  \
# 30  Bobby's parent talked to the doctor
#
#                                                 text3  Interestingness  \
# 30  The doctor released Bobby in time for him to p...              1.0
#
#    흥미 요인 (평점 2 이상)    비흥미 요인 (평점 1)  \
# 30             NaN  예측 가능한 전개 또는 결말
#
#                                         Description
# 30  no dramatic accident. need of more discriptions

# %%
hcard1_c = hcard_df1[(hcard_df1['Interestingness'] == 1.0) & (hcard_df1['비흥미 요인 (평점 1)'] == '진부함(Cliche)')]
hcard1_c
# Out:
#     card1  card2 card3                                              text1  \
# 3     B_11  B_27  B_13              John is a poor man and does odd jobs.
# 35    B_23  A_11   A_8  Philip is fond of singing and his dream is to ...
# 176   A_13  A_19  A_35  Lisa was always alone. She spent her days watc...
# 199   A_30   A_6   A_8  A Happy Pregnant Mother , TWINLKLE wanted his ...
# 254   A_19  B_21  A_35  On the way to work Brenda was not paying atten...
#
#                                                  text2  \
# 3                  He tries his luck by playing poker.
# 35   He worked hard, practiced daily and started si...
# 176  Lisa went out to get more donuts and she got i...
# 199  As per the mother wish and prayers become real...
# 254  Brenda was very distressed and went to talk to...
#
#                                                  text3  Interestingness  \
# 3              He wins big and becomes rich overnight.              1.0
# ...

# %%
hcard1_e = hcard_df1[(hcard_df1['Interestingness'] == 1.0) & (hcard_df1['비흥미 요인 (평점 1)'] == '기타')]
hcard1_e
# Out:
#    card1  card2 card3                                              text1  \
# 73    B_4  A_24  A_14  On her way to the beach, Mary takes a wrong tu...
#
#                                                 text2  \
# 73  The wrong turn take her through the forest, bu...
#
#                                                 text3  Interestingness  \
# 73  The road ups up at the most beautiful spot on ...              1.0
#
#    흥미 요인 (평점 2 이상) 비흥미 요인 (평점 1)        Description
# 73             NaN            기타  no plot structure

# %%
hcard1_n = hcard_df1[(hcard_df1['Interestingness'] == 1.0) & (hcard_df1['비흥미 요인 (평점 1)'] == '평범한 소재')]
hcard1_n
# Out:
#     card1  card2 card3                                              text1  \
# 34    A_13  B_40  B_31         Sarah had been eating way too many sweets.
# 40    B_38  B_40  A_35  Angela was getting ready for a special date to...
# 49    A_30  A_40  A_27  Mary had not been feeling well and was worried...
# 55    B_19  A_28  B_34  Clinton was unhappy because he needed to lose ...
# 58    B_12  B-38   B_1  Anne Was eagerly waiting for 23rd of that mont...
# ..     ...   ...   ...                                                ...
# 343   A_35  A_25  A_22                      A BOY AND A GIRL FELL IN LOVE
# 344    A_1  A_21   B_1                    Tobey was in the hospital sick.
# 346   A-36  B-38   B-6  Caroline return to home from school  with thin...
# 347    A_1  A_28  B_23  Felix was admitted in a hospital where he was ...
# 348   A_36  A_22  A_35  Mike had a crush on Missy, but he was too scar...
#
#                                                  text2  \
# ...

# %%
hcard1_f["card2"].value_counts()
# Out:
# A_40    12
# A_29     7
# A_1      6
# A_30     6
# A_28     6
#         ..
# A_23     1
# A_37     1
# A_19     1
# B_13     1
# A_20     1
# Name: card2, Length: 65, dtype: int64

# %%
hcard1_f2 = hcard1_f[hcard1_f['card2'] == 'A_40']
hcard1_f2
# Out:
#     card1  card2 card3                                              text1  \
# 0      A_1  A_40  A_35  Tom was sick and spent many days in the hospit...
# 9      A_1  A_40  A_12  Lisa is very upset because she is sick in the ...
# 10    A_30  A_40  A_27           Anna Jonas is expecting her first child.
# 15     A_1  A_40  B_20  Joanna, a travel writer, had become bedridden ...
# 120    A_1  A_40  A_22         The boy was laying in a hospital bed sick.
# 133   A_13  A_40  B_31        Emily sat at home eating junk food all day.
# 171    A_1  A_40   A_6  Timmy was sad because he was sick in the hospi...
# 182    A_1  A_40  A_28  Bobby had cancer and spent a lot of time in th...
# 188    A_1  A_40  A_35  Bobby has been in the hospital for a week and ...
# 207    A_1  A_40  B_23  Jonathan has been sick for a week now and is i...
# 247   B_17  A_40  A_28                          Jack has severe head pain
# 253    A_1  A_40  A_28                    David was very sick as a child.
#
# ...

# %%
hcard1_f2['text2']
# Out:
# 0                     A new doctor came in to treat Tom.
# 9                Dr. Rick comes and gives Lisa medicine.
# 10            She consulted her family doctor Mr. David.
# 15     They conducted numerous tests and discovered t...
# 120                 The doctor came in with the results.
# 133    The doctor asked her to stop her bad habits an...
# 171    The doctor came and figured out what was wrong...
# 182    A doctor prescribe a new experimental treatmen...
# 188    Dr. Smith gave Bobby the good news that he's w...
# 207    The doctor comes to Jonathans with possible go...
# 247                              Jack went to the doctor
# 253    Fortunately, the doctors were able help David ...
# Name: text2, dtype: object

# %%
nltk.download('stopwords')                                                                               
nltk.download('punkt')

A_40_dialogues = ' '.join(
    hcard1_f2['text2'])

first_names = []
for character in hcard1_f2['card2'].to_list()[:len(hcard1_f2['card2'].to_list())//2]:
    if len (character.split(' ')) > 1:
        first_names.append(character.split(' ')[0])
        
stopwords = nltk.corpus.stopwords.words('english')

A_40_dialogueslist = [A_40_dialogues]
for token in word_tokenize(A_40_dialogues):
    if ((len(token) != 1) and ('...' not in token) and ("'" not in token)) and \
                              (":" not in token) and ("--" not in token) and \
                              ("Dumbledore" not in token) and \
                              (token.lower() not in stopwords) and (token not in first_names):
        A_40_dialogueslist.append(token)
        
words_frequencies1 = dict(Counter(A_40_dialogueslist))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
words_cloud = WordCloud(background_color='black', width=800, height=400, colormap='Set2',
                        max_words=2000).generate_from_frequencies(words_frequencies1)
        
plt.figure(figsize=[15,15])
plt.imshow(words_cloud, interpolation = 'bilinear')
plt.axis("off")
plt.show()

# %%
hcard1_f["card3"].value_counts()
# Out:
# A_35    14
# A_8     12
# A_28     9
# B_13     9
# A_27     8
# B_23     7
# A_6      5
# A_40     5
# B_31     5
# B_24     4
# B_20     4
# B_35     4
# B_33     4
# A_30     3
# A_22     3
# B_38     3
# A_23     3
# A_3      3
# B_1      3
# B23      2
# A_11     2
# B_14     2
# A_13     2
# B_30     2
# B_39     2
# A_4      2
# A_12     2
# A_24     1
# A-28     1
# A8       1
# B24      1
# a30      1
# A_21     1
# A_29     1
# B31      1
# A_37     1
# B40      1
# A6       1
# A_17     1
# B30      1
# B_17     1
# A3       1
# B_11     1
# B-13     1
# b_20     1
# Name: card3, dtype: int64

# %%
hcard1_f3 = hcard1_f[hcard1_f['card3'] == 'A_35']
hcard1_f3
# Out:
#     card1  card2 card3                                              text1  \
# 0      A_1  A_40  A_35  Tom was sick and spent many days in the hospit...
# 14    A_36   B_1  A_35                         Euvi loved Manik very much
# 16    A_27   A_4  A_35      When Tom was a baby, his sister went missing.
# 37    A_30   B_4  A_35                            Mary was bored at home.
# 63    A_36  A_22  A_35  Leonard met a girl at school whom he thought w...
# 134   B_21  A_36  A_35                             Mary Has no boy friend
# 137   A_36   B_5  A_35  Amy get ignored by john due to some misunderst...
# 138    A_1  A_17  A_35  The boy was very sick. So he is admitted in th...
# 188    A_1  A_40  A_35  Bobby has been in the hospital for a week and ...
# 208    B_1  A_11  A_35                      One day Lisa proposed to Tom.
# 215   A_22  A_36  A_35  Benjamin told Olivia that he was going to have...
# 257   A_26  A_21  A_35    A man dreamed of leading a simple farming life.
# ...

# %%
hcard1_f3['text3']
# Out:
# 0      Tom is now fully healed and happy with his new...
# 14     Manik understands Euvi's love to him and accep...
# 16     A few days later, she was found and reunited w...
# 37                 Mary saw a friend and gave him a hug.
# 63     They both realized they were meant for each ot...
# 134                   Mary and mathew has fallen in love
# 137    Finally John realized his mistake and he talke...
# 138                  After a long time he met his friend
# 188      Bobby is very happy to finally see Susie again.
# 208                      Finally Tom and Lisa are Happy.
# 215    The six month training for work had come to an...
# 257    After waiting a long time, he finally found a ...
# 282    Then they re united happily and hugged each ot...
# 296    They were happy to meet after long gap and hug...
# Name: text3, dtype: object

# %%
A_35_dialogues = ' '.join(
    hcard1_f3['text3'])

first_names = []
for character in hcard1_f3['card3'].to_list()[:len(hcard1_f3['card3'].to_list())//2]:
    if len (character.split(' ')) > 1:
        first_names.append(character.split(' ')[0])
        
stopwords = nltk.corpus.stopwords.words('english')

A_35_dialogueslist = [A_35_dialogues]
for token in word_tokenize(A_35_dialogues):
    if ((len(token) != 1) and ('...' not in token) and ("'" not in token)) and \
                              (":" not in token) and ("--" not in token) and \
                              ("Dumbledore" not in token) and \
                              (token.lower() not in stopwords) and (token not in first_names):
        A_35_dialogueslist.append(token)
        
words_frequencies2 = dict(Counter(A_35_dialogueslist))

# %%
words_cloud = WordCloud(background_color='black', width=800, height=400, colormap='Set2',
                        max_words=2000).generate_from_frequencies(words_frequencies2)
        
plt.figure(figsize=[15,15])
plt.imshow(words_cloud, interpolation = 'bilinear')
plt.axis("off")
plt.show()
